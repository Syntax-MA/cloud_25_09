# %%
for i in range(3):
    print("hello")
# Out:
# hello
# hello
# hello

# %%
def greet():
    # Code in der Funktion
    # Code in der Funktion
    # Code in der Funktion
    print("hello")

# kein Code in der Funktion
print("regulärs skript")

greet()
greet()
greet()

print("hier passiert etwas anderes")

greet()
# Out:
# regulärs skript
# hello
# hello
# hello
# hier passiert etwas anderes
# hello

# %%
def party():
    print("wohoooO!")
    print("wohoooO!")
    print("wohoooO!")

print("Start")

party()

print("Stop")
# Out:
# Start
# wohoooO!
# wohoooO!
# wohoooO!
# Stop

# %%
def greet(name):  # name ist der parameter

    print(f"Hello {name}!")

print("Start")

greet("Bob")     # "Bob" ist das argument
greet("Stacy")
greet("R2D2")

print("Stop")
# Out:
# Start
# Hello Bob!
# Hello Stacy!
# Hello R2D2!
# Stop

# %%
def print_sum(a, b):
    summe = a + b
    print(f"Die Summe deiner Zahlen lautet {summe}")


user_input_a = int(input("Gib eine erste Zahl ein: "))
user_input_b = int(input("Gib eine zweite Zahl ein: "))

print_sum(user_input_a, user_input_b)


#print_sum(1, 2)
#print_sum(4, 3)
# Out:
# Die Summe deiner Zahlen lautet 22

# %%
def print_sum(a, b):
    summe = a + b
    print(f"Die Summe deiner Zahlen lautet {summe}")


print_sum(int(input("Gib eine erste Zahl ein: ")), int(input("Gib eine zweite Zahl ein: ")))
# Out:
# Die Summe deiner Zahlen lautet 11

# %%
def berechne_summe(a, b):
    return a + b

print(f"5 + 5 macht {berechne_summe(5, 5)} und 2 + 2 macht {berechne_summe(2, 2)}")
# print("5 + 5 macht 10 und 2 + 2 macht 4")

ergebnis = berechne_summe(5, 5) # 10

print(ergebnis)
# Out:
# 5 + 5 macht 10 und 2 + 2 macht 4

# %%
def return_stuff():
    return [1, 2 , 3]

print(return_stuff())

def add_one(zahl):
    return zahl + 1

print(add_one(2))
# Out:
# [1, 2, 3]
# 3

# %%
variable_global = "hello_global"

def multiverse_1():
    variable_local = "hello_local"
    print(variable_local)
    print(variable_global)
    # Thanos Snap muliverse_1 wird gelöscht

multiverse_1() # alles passiert hier

print("#########")
print(variable_global)
# print(variable_local) würde fehler erzeugen, da die lokale Variable nicht existiert
# Out:
# hello_local
# 10
# #########
# 10

# %%
x_global = 5

##################
def greet():

    y_local = 10
    x_global = 15    # ! Achtung !
    print("Funktion start")
    print(f"Die globale Variable ist {x_global}")
    print(f"Die lokale Variable ist {y_local}")
    print("Funktion stop")
##################

print("main programm start")

greet() # <- Funktionsaufruf

print("######## Code dannach ###########")
print(f"Die globale Variable ist {x_global}")
#print(f"Die lokale Variable der Funktion greet() ist {y_local}")
# Out:
# main programm start
# Funktion start
# Die globale Variable ist 15
# Die lokale Variable ist 10
# Funktion stop
# ######## Code dannach ###########
# Die globale Variable ist 5

# %%
x_global = 5

##################
def greet():

    y_local = 10
    global x_global
    x_global = 15

    print("Funktion start")
    print(f"Die globale Variable ist {x_global}")
    print(f"Die lokale Variable ist {y_local}")
    print("Funktion stop")
##################

print("main programm start")

greet() # <- Funktionsaufruf

print("######## Code dannach ###########")
print(f"Die globale Variable ist {x_global}")
#print(f"Die lokale Variable der Funktion greet() ist {y_local}")
# Out:
# main programm start
# Die globale Variable ist 5
# Die globale Variable ist 15
# Funktion start
# Die lokale Variable ist 10
# Funktion stop
# ######## Code dannach ###########
# Die globale Variable ist 15
