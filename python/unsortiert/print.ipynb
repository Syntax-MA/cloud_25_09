# %%
print("Wort1", "Wort2")
print("Wort1", "Wort2", sep="*", end="!!!")
print("extra")
print(f"")
# Out:
# Wort1 Wort2
# Wort1*Wort2!!!extra

# %%
print("hello"[0])
# Out:
# h

# %%
name = "Anna"

if name.startswith("A") == True:
    print("yay")
# Out:
# yay
