# %%
print("hello world")
print(5)


if True:
  print("hello")
  if True:
      print("auch das")  


print("jetzt weiter im code")
# Out:
# hello world
# 5
# hello
# auch das
# jetzt weiter im code
# hello

# %%
user_input = "hello"

print(user_input)

# snake_case <---
# camelCase
# PascalCase
# kebab-case
# Out:
# hello

# %%
my_string_1 = "Hallo"
my_string_2 = 'Hallo'
my_string_3 = """Hallo das ist ein
ganz langer string.
Der mehrere Zeilen nutzt."""

print(my_string_3)
# Out:
# Hallo das ist ein
# ganz langer string.
# Der mehrere Zeilen nutzt.

# %%
name = "World"

my_fstring = f"Hello { name }"

print(my_fstring)
# Out:
# Hello World

# %%
print("hello", "world", "again",sep= "❤️", end= "👌" )
print("hello", "world", "again",sep= "❤️", end= "👌\n" )

print("Ich möchte gerne \n zwei Zeilen \n oder sogar drei.")
# Out:
# hello❤️world❤️again👌hello❤️world❤️again👌
# Ich möchte gerne
#  zwei Zeilen
#  oder sogar drei.

# %%
name = input("wer?")
print(name)
# Out:
# re

# %% [markdown]
# Aufgabe 13: Preis mit zwei Nachkommastellen anzeigen
# Ergänze den Code, um den Preis in Euro auf zwei Nachkommastellen anzuzeigen.

# %%
preis = 19.995
print(f"Der Preis beträgt {preis:.2f} €")


preis_str = str(preis)
print(preis)
print(preis_str)
# Out:
# Der Preis beträgt 20.00 €
# 19.995
# 19.995

# %%
import math

preis = 19.995
preis_gekürzt = math.floor(preis * 100) / 100
print(f"Der Preis beträgt {preis_gekürzt:.2f} €")

# %%
if True and True or False:
#->.    True.    or False
    print("1")

if True and False or False:
#->.    False     or False
    print("2")

if False and False or True:
#->.     False.    or True
    print("3")
# Out:
# 1
# 3

# %% [markdown]
# string
# integer
# float
# boolean
#
# list = ["Apfel", "Banane", "Kiwi"]

# %%
obstkorb = ["Apfel", "Banane", "Kiwi"]

print(obstkorb)
print(obstkorb[0])
print(obstkorb[1])
print(obstkorb[2])
# Out:
# ['Apfel', 'Banane', 'Kiwi']
# Apfel
# Banane
# Kiwi

# %%
for i in range(3): # range(0, 3, 1)
    print(i)

print("ende")
# Out:
# 0
# 1
# 2
# ende

# %%
for i in range(3, 7): # range(3, 7, 1)
    print(i)

print("ende")
# Out:
# 3
# 4
# 5
# 6
# ende

# %%
for i in range(3, 5, 1):
    print(i)

print("ende")
# Out:
# 3
# 4
# ende

# %%
obstkorb = ["Apfel", "Banane", "Kiwi"]

for obst in obstkorb:
    print(obst)
# Out:
# Apfel
# Banane
# Kiwi

# %%
for i in range(len(obstkorb)):
    print(i, obstkorb[i])
# Out:
# 0 Apfel
# 1 Banane
# 2 Kiwi

# %%
for index, obst in enumerate(obstkorb):
    print(index, obst)

    print(f"Auf Platz {index + 1} ist {obst}")
# Out:
# 0 Apfel
# Auf Platz 1 ist Apfel
# 1 Banane
# Auf Platz 2 ist Banane
# 2 Kiwi
# Auf Platz 3 ist Kiwi

# %%
zahl = 5

#zahl = zahl + 2

zahl *= 2

print(zahl)
# Out:
# 10

# %%
for i in range(10):
    if i == 7:
        break
    print("hello")
# Out:
# hello
# hello
# hello
# hello
# hello
# hello
# hello

# %%
obstkorb = ["Apfel", "Brot", "Banane", "Kiwi"]

for index, obst in enumerate(obstkorb):
    
    if obst == "Banane":
        print(f"Banane ist auf dem Platz { index + 1 }.")
        break

    print(index, obst)
    print(f"Auf Platz {index + 1} ist {obst}")

print("jetzt ist der Spaß vorbei!")
# Out:
# 0 Apfel
# Auf Platz 1 ist Apfel
# 1 Brot
# Auf Platz 2 ist Brot
# Banane ist auf dem Platz 3.
# jetzt ist der Spaß vorbei!

# %%
for i in range(5):

    print("Die aktuelle Zahl lautet: ")

    if i == 3:
        continue

    print(i)
    print("wohoo")

print("ende")
# Out:
# Die aktuelle Zahl lautet:
# 0
# wohoo
# Die aktuelle Zahl lautet:
# 1
# wohoo
# Die aktuelle Zahl lautet:
# 2
# wohoo
# Die aktuelle Zahl lautet:
# Die aktuelle Zahl lautet:
# 4
# wohoo
# ende

# %%
name = "Tony"
print(name[0])
print(name[1])
print(name[2])
print(name[-1])


cities = ["NY", "Texas", "Neuss", "Berlin"]

for city in cities:

    if city[0] != "B":
        continue

    print(f"Dicke Party in {city}")

print("Kommt alle mit")
# Out:
# T
# o
# n
# y
# Dicke Party in Berlin
# Kommt alle mit

# %%
text = "1b3"

print(text.isnumeric())
# Out:
# False
