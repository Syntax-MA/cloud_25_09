# %% [markdown]
# Wenn neues Projekt, oder neuer Projektordner
#
# Ist es sinnvoll eine pythen virtual environment zu erstellen (venv)
#
# import pandas
# import time
# import date from time
#
# falls Modul / Paket noch nicht auf dem PC, dann muss es runtergeladen werden z.B mit dem Paktemanager pip (übers Terminal)
#
# um eine venv zu erstellen:
#
# python3 -m venv venv
# source venv/bin/activate
#
# ```bash
# Dann können wir anfangen .py Dateien zu erstellen.
# Diese können gestartet werden normal mit dem Terminal Befehl
# python3 dateiname.py
# ```
#
# Wenn wir jupyter Notebooks verwenden wollen.
# Das sind Dateien die auf .ipynb // interactive python notebook
#
# Wenn wir wir diese in Kombination mit venv verwenden wollen.
#
# ```bash
# pip install ipykernel jupyter
# ```
#
# offizieller Style Guide pep 8 : https://peps.python.org/pep-0008/

# %%
# Single Line komentieren ab der Raute

"""
Multiline Kommentaren
Egal wo im Code
"""

####################################
# Variablen
####################################


x = 3 # Variable Definieren und zuweisen in einem Schritt

# Primitve Datentypen

my_string = "Zeichen in Anführungstrichen"
my_int = 5                  # Ganze Zahl
my_float = 3.5              # Fließkommazahl
my_bool = True              # boolean -> True / False

# Mathe yay!

x = 5
y = 3

summe = x + y
minus = x - y
multiplakation = x * y

# Möglichkeiten:  + - * / % **

# String operations

word_a = "Apple"
word_b = "pen"

uuuh = word_a + word_b
# uuh = "Apple" + "pen"
# uuh = "Applepen"

print(uuuh) # --> "Applepen"


# nicht primitve datenstrukturen

# list
my_list = [ "Haus", 2, True, "Andere Datentypen" ] # auch aus anderen Sprachen bekannt als -> Array 
# veränderbar           und geordnet        doppelte möglich

# tuple
my_tuple = ( "Haus", 2, True, "auch weitere Datentypen" )
# nicht veränderbar     und geordnet        doppelte möglich

# Bei den geordneten Datentypen können wir auf einzelne Werte zugreifen über den Index
print(my_list[0]) # durch das Angeben des Index in eckigen klammern
print(my_tuple[0])

my_list[0] = "Maus"
print(my_list)

# set 
my_set = { "Haus", 2, True }
# veränderbar           und nicht geordnet  doppelte nicht möglich

"""
Eine Möglichkeit die Eigenschaften zu nutzen
if len(my_list) == len(set(my_list)):
    print("ist gleichlang")
else:
    print("NOT")
"""

# dictionaries -> in anderen Sprachen object, hashmap ...
# sehr beliebt durch das Dateiformat JSON
# Eine häufigsten strukturen für API Schnittstellen in der Web Entwicklung.

my_dict = {
    "key": "value",
    "name": "bob",
    3: 17,
    7: True
}
# veränderbar           und nicht geordnet  doppelte schlüssel nicht möglich

print(my_dict["key"])


# Kontrollstrukturen

if x > 3:
    print("X ist größer 3")
# optional dannach:
elif x == 3:
    print("x ist gleich 3")
# optional dannach:
else:
    "alles das die ersten Bedingungen nicht erfüllt hat."

# == != < > >= <= 
# and or not
# klammern können auch genutzt werden

if not(x >= 1) and (y == 2):
    print("do kram")

# Schleifen
# for und while
# schlüsselbegriffe: break continue

while True:  # in dieser Form eine !Endlosschleife! kann durch eine BEdingung z.B. x > 2 ausgetauscht werden
    print("hello")
    if x == 3:
        x = 0
    elif x == 2:
        x == 2
        continue      # skipt die weiteren Schritte dieser Schleife und geht direkt in die nächste Iteration
    else:
        break         # beendet eine Schleife komplett

    print("hello again") # auch das ist in der Schleife!


for index in range(5): # range(start, stop, step) -> range(1, 6, 2)
    print(index)

for element in my_list:
    print(element)

#for index in range(len(my_list)):
#    print(index)

for i, e in enumerate(my_list):
    print(i)
    print(e)

# schleifen mit dictionaries
# .keys() # der default daher nicht wirklich nötig
# .values()
# .items()


for item in my_dict.items():  # alternativ .values() oder wenn nichts dahinter, bekommt man die keys
    print(item)
    print(item[0])
    print(item[1])

# listen und dictionaries kommen oft nicht allein, sondern als durcheinander

my_chaos = [
    {
        "key1": "value1",
        "key2": ["Alice", "doch you like rabbits?"]
    },
    ["Why so serious", "We are takinbg the Hobbits to Isengard"]
]

print(f"Who the heck is {my_chaos[0]["key2"][0]}")

# functions

def my_func(param1, param2):
    print(f"I am a function and this is param1: {param1} and this is param2: {param2}")

# aufrufen nicht vergesse!

my_func("argument_1", "argument_2")
# Out:
# Applepen
# Haus
# Haus
# ['Maus', 2, True, 'Andere Datentypen']
# value
# X ist größer 3
# hello
# 0
# 1
# 2
# 3
# 4
# Maus
# 2
# True
# Andere Datentypen
# 0
# Maus
# 1
# 2
# 2
# True
# 3
# Andere Datentypen
# ('key', 'value')
# key
# value
# ('name', 'bob')
# name
# bob
# (3, 17)
# 3
# 17
# (7, True)
# 7
# True
# Who the heck is Alice
# I am a function and this is param1: argument_1 and this is argument_2
