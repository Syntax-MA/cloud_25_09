# %% [markdown]
# Übung 2: Koordinatensystem
# Aufgabe:
#
# Erstelle ein Programm für ein 2D-Koordinatensystem:
#
# Erstelle mehrere Punkte als Tuples (x, y) Koordinaten
#
# Punkt A: (0, 0)
# Punkt B: (3, 4)
# Punkt C: (6, 8)
# Punkt D: (3, 4)
# Speichere alle Punkte in einer Liste
#
# Berechne für jeden Punkt die Distanz zum Ursprung (0, 0)
#
# Formel: sqrt(x² + y²) bzw. (x² + y²) ** 0.5
#
# (x ** 2 + y ** 2) ** 0.5
#
# Prüfe, ob es doppelte Punkte gibt
#
# Zähle wie oft Punkt B (3, 4) vorkommt
# Entpacke die Koordinaten von Punkt C und gib x und y einzeln aus
#
# Erstelle ein Tuple mit allen Distanzen und gib es aus
#
# Hinweise:
#
# Tuples eignen sich perfekt für Koordinaten (unveränderlich)
# Nutze tuple.count() zum Zählen
# Nutze Tuple Unpacking: x, y = punkt
# Du kannst Tuples in Listen speichern

# %%
punkt_a = (0, 0)
punkt_b = (3, 4)
punkt_c = (6, 8)
punkt_d = (3, 4)

koordinaten_list = [punkt_a, punkt_b, punkt_c, punkt_d]

distanzen_list = []

for punkt in koordinaten_list:
    
    print(punkt)
    print(f"Die X Koordinate lautet {punkt[0]}")
    print(f"Die Y Koordinate lautet {punkt[1]}")

    distanz = (punkt[0] ** 2 + punkt[1] ** 2) ** 0.5
    distanzen_list.append(distanz)

print(distanzen_list)
distanzen_tuple = tuple(distanzen_list)
print(distanzen_tuple)


koordinaten_set = set(koordinaten_list)

if len(koordinaten_list) == len(koordinaten_set):
    print("Keine Dopplungen.")
else:
    print("Es gibt doppelte.")


not_unique_points = {}

for points in cords:
    cords_counter = cords.count(points)
    if cords_counter >= 1:
        not_unique_points.update({points: cords_counter})

print(not_unique_points)
# Out:
# (0, 0)
# Die X Koordinate lautet 0
# Die Y Koordinate lautet 0
# (3, 4)
# Die X Koordinate lautet 3
# Die Y Koordinate lautet 4
# (6, 8)
# Die X Koordinate lautet 6
# Die Y Koordinate lautet 8
# (3, 4)
# Die X Koordinate lautet 3
# Die Y Koordinate lautet 4
# [0.0, 5.0, 10.0, 5.0]
# (0.0, 5.0, 10.0, 5.0)
# Es gibt doppelte.
